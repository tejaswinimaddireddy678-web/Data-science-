# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswinimaddireddy678-web/Data-science-/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#eda--exploratory data analysis
#it is the process of understanding and analyzing data before building models
#we need to check
#is there any missing values,duplicates,what pattern exist,what columns are important, is the dataset is balanced or not,
#without eda
#we may train model on wrong data,missing values create errors,outliers can reduce accuracy

# %%
#complete eda steps

# %%
#step1 import libraries

# %%
import seaborn as sn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#dataset loading
df=sn.load_dataset('titanic')

# %%
#view data set
df.head() # show first 5 rows

# %%
df.tail() #show last 5 rows

# %%
df.sample() #random values

# %%
#understanding data structures
df.shape # it will tells  how many rows and columns
# Out:
# (891, 15)

# %%
df.columns # it will give how many columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#df.info  --- show datatypes,non null values,data types
df.info()

# %%
df.dtypes #showing dtypes

# %%
#statistical summary --- mean,min,max,variance
df.describe()

# %%
#we have to check missing values
df.isnull()

# %%
df.isnull().sum()

# %%
#we have to fill that values by using fillna methods(mean,mode,median,logic)

# %%
#we have to delete those rows and columns by using drop

# %%
#we have to check duplicate records
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
#if we have duplicate records just we will remove those records drop

# %%
#correlation analysis
df.corr(numeric_only=True)

# %%
#outliers-visualization
#data set balanced or imbalanced
#feature engineering
#21-09-2002=> 21 09 2002
